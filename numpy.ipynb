# %%
import numpy as np

a1 = np.array([1,2,3,4])
print(f"1D Array : {a1}")

a2 = np.array([
    [1,2,3],
    [4,5,6]
])
print(f"2D Array : {a2}")
# Out:
# 1D Array : [1 2 3 4]
# 2D Array : [[1 2 3]
#  [4 5 6]]
